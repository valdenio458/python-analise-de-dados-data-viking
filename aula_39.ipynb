# %% [markdown]
# <a href="https://colab.research.google.com/github/valdenio458/python-analise-de-dados-data-viking/blob/main/aula_39.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Visualização de dados com Matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Gráfico de linhas

# %%
np.random.seed(7)

# Array com números aleatórios inteiros entre 1 e 1500, com 10 amostras
y = np.random.randint(low=1, high=1500, size=10)

# %%
y
# Out:
# array([ 176, 1221,  538,  503,  212,  920, 1373, 1210, 1423,  536])

# %%
plt.plot(y)

# %%
# Insere a primeira linha no plot
# ms = tamanho do marcador
# mec = cor da linha do marcador
plt.plot(y, color='#749187', marker='o', ms=5, mec='k', markerfacecolor='w', ls='-.')

# Insere a segunda linha
plt.plot(y*2, marker='+', color='k', ms=7)

# Rótulos
plt.xlabel('Eixo X', color='red', size=12)
plt.ylabel('Eixo Y')
plt.title('Título', loc='left')

# Gridlines
# alpha = opacidade
plt.grid(axis='y', color='gray', linestyle='--', linewidth=1, alpha=0.8)

# %% [markdown]
# ### Subplots

# %%
np.random.seed(6)
x = np.arange(1, 11)
y1 = np.random.randint(1, 400, 10)
y2 = np.random.randint(150, 500, 10)
y3 = np.random.randint(200, 600, 10)

plt.figure(figsize=(15, 5))
plt.suptitle('Figura', fontsize=15)

plt.subplot(1, 3, 1)
plt.plot(x, y1, color='k')
plt.title('Subplot 1', pad=10)
plt.xlabel('Exixo X')
plt.ylabel('Exixo Y')

plt.subplot(1, 3, 2)
plt.plot(x, y2, color='r')
plt.title('Subplot 2', pad=10)
plt.xlabel('Exixo X')
plt.ylabel('Exixo Y')

plt.subplot(1, 3, 3)
plt.plot(x, y3, color='g')
plt.title('Subplot 3', pad=10)
plt.xlabel('Exixo X')
plt.ylabel('Exixo Y')

# Aumentar espaçamento
plt.tight_layout(pad=4)

# %%
# Outra forma de fazer a mesma plotagem
fig, ax=plt.subplots(1, 3, figsize=(15, 5))
fig.suptitle('Figure')
ax[0].plot(x, y1, color='black')
ax[1].plot(x, y2, color='red')
ax[2].plot(x, y3, color='green')

for i in range(3):
   ax[i].set(title= f'Subplot {i+1}', xlabel='Eixo X', ylabel='Eixo Y')
